# %%
import json
import math

with open('inverted_index.json', 'r') as f:
    inverted_index = json.load(f)

# The number of documents in the collection
num_docs = len(set(doc_id for postings_list in inverted_index.values() for doc_id in postings_list))

# The number of terms in the collection
num_terms = len(inverted_index)

# The total number of occurrences of all terms in the collection
total_term_freq = sum(len(postings_list) for postings_list in inverted_index.values())

# The average document length (in terms)
avg_doc_len = total_term_freq / num_docs

# The document frequency (DF) and inverse document frequency (IDF) for each term
dfs = {}
idfs = {}
for term, postings_list in inverted_index.items():
    dfs[term] = len(postings_list)
    idfs[term] = math.log(num_docs / dfs[term])


print(f'Number of documents: {num_docs}')
print(f'Number of terms: {num_terms}')
print(f'Total term frequency: {total_term_freq}')
print(f'Average document length: {avg_doc_len:.2f}')
print('Top 10 Term Frequencies:')
for term, df in sorted(dfs.items(), key=lambda x: x[1], reverse=True)[:10]:
    print(f'{term}: {df}')

# print(idfs)
print('Top 10 Inverse Document Frequencies:')
for term, idf in sorted(idfs.items(), key=lambda x: x[1], reverse=True)[:10]:
    print(f'{term}: {idf:.2f}')
# Out:
# Number of documents: 475
# Number of terms: 40169
# Total term frequency: 347727
# Average document length: 732.06
# Top 10 Term Frequencies:
# one: 432
# time: 409
# like: 384
# look: 368
# see: 360
# go: 359
# day: 354
# get: 354
# back: 352
# said: 347
# Top 10 Inverse Document Frequencies:
# adlertxt: 6.16
# dunubian: 6.16
# carbonium: 6.16
# belitsheri: 6.16
# prisca: 6.16
# unmention: 6.16
# commitedli: 6.16
# fadler: 6.16
# bragi: 6.16
# celin: 6.16

# %%
from collections import defaultdict

idf_counts = defaultdict(int)

for term, idf in idfs.items():
    idf_counts[idf] += 1


print('IDF statistic:')
for idf, count in sorted(idf_counts.items(), reverse=True):
    print(f'{count} terms have an IDF of {idf:.2f}')
# Out:
# IDF statistic:
# 22509 terms have an IDF of 6.16
# 4728 terms have an IDF of 5.47
# 2149 terms have an IDF of 5.06
# 1404 terms have an IDF of 4.78
# 993 terms have an IDF of 4.55
# 795 terms have an IDF of 4.37
# 621 terms have an IDF of 4.22
# 524 terms have an IDF of 4.08
# 428 terms have an IDF of 3.97
# 391 terms have an IDF of 3.86
# 318 terms have an IDF of 3.77
# 273 terms have an IDF of 3.68
# 251 terms have an IDF of 3.60
# 223 terms have an IDF of 3.52
# 194 terms have an IDF of 3.46
# 188 terms have an IDF of 3.39
# 168 terms have an IDF of 3.33
# 132 terms have an IDF of 3.27
# 132 terms have an IDF of 3.22
# 123 terms have an IDF of 3.17
# 140 terms have an IDF of 3.12
# 109 terms have an IDF of 3.07
# 107 terms have an IDF of 3.03
# 103 terms have an IDF of 2.99
# 92 terms have an IDF of 2.94
# 83 terms have an IDF of 2.91
# 76 terms have an IDF of 2.87
# 96 terms have an IDF of 2.83
# 56 terms have an IDF of 2.80
# 71 terms have an IDF of 2.76
# 68 terms have an IDF of 2.73
# 69 terms have an IDF of 2.70
# 73 terms have an IDF of 2.67
# 64 terms have an IDF of 2.64
# 55 terms have an IDF of 2.61
# 65 terms have an IDF of 2.58
# 61 terms have an IDF of 2.55
# 44 terms have an IDF of 2.53
# 44 terms have an IDF of 2.50
# 57 terms have an IDF of 2.47
# 38 terms have an IDF of 2.45
# 47 terms have an IDF of 2.43
# 43 terms have an IDF of 2.40
# 59 terms have an IDF of 2.38
# 39 terms have an IDF of 2.36
# 44 terms have an IDF of 2.33
# 38 terms have an IDF of 2.31
# 42 terms have an IDF of 2.29
# 39 terms have an IDF of 2.27
# 33 terms have an IDF of 2.25
# 36 terms have an IDF of 2.23
# 24 terms have an IDF of 2.21
# 30 terms have an IDF of 2.19
# 31 terms have an IDF of 2.17
# 35 terms have an IDF of 2.16
# 37 terms have an IDF of 2.14
# 29 terms have an IDF of 2.12
# 31 terms have an IDF of 2.10
# 30 terms have an IDF of 2.09
# 24 terms have an IDF of 2.07
# 34 terms have an IDF of 2.05
# 30 terms have an IDF of 2.04
# 20 terms have an IDF of 2.02
# 17 terms have an IDF of 2.00
# 21 terms have an IDF of 1.99
# 26 terms have an IDF of 1.97
# 18 terms have an IDF of 1.96
# 22 terms have an IDF of 1.94
# 18 terms have an IDF of 1.93
# 19 terms have an IDF of 1.91
# 19 terms have an IDF of 1.90
# 26 terms have an IDF of 1.89
# 21 terms have an IDF of 1.87
# 24 terms have an IDF of 1.86
# 21 terms have an IDF of 1.85
# 16 terms have an IDF of 1.83
# 20 terms have an IDF of 1.82
# 14 terms have an IDF of 1.81
# 21 terms have an IDF of 1.79
# 15 terms have an IDF of 1.78
# 18 terms have an IDF of 1.77
# 10 terms have an IDF of 1.76
# 20 terms have an IDF of 1.74
# 7 terms have an IDF of 1.73
# 17 terms have an IDF of 1.72
# 12 terms have an IDF of 1.71
# 16 terms have an IDF of 1.70
# 18 terms have an IDF of 1.69
# 13 terms have an IDF of 1.67
# 23 terms have an IDF of 1.66
# 11 terms have an IDF of 1.65
# 9 terms have an IDF of 1.64
# 17 terms have an IDF of 1.63
# 14 terms have an IDF of 1.62
# 17 terms have an IDF of 1.61
# 6 terms have an IDF of 1.60
# 13 terms have an IDF of 1.59
# 11 terms have an IDF of 1.58
# 6 terms have an IDF of 1.57
# 10 terms have an IDF of 1.56
# 9 terms have an IDF of 1.55
# 10 terms have an IDF of 1.54
# 9 terms have an IDF of 1.53
# 10 terms have an IDF of 1.52
# 6 terms have an IDF of 1.51
# 10 terms have an IDF of 1.50
# 11 terms have an IDF of 1.49
# 8 terms have an IDF of 1.48
# 8 terms have an IDF of 1.47
# 12 terms have an IDF of 1.46
# 9 terms have an IDF of 1.45
# 5 terms have an IDF of 1.44
# 9 terms have an IDF of 1.44
# 13 terms have an IDF of 1.43
# 7 terms have an IDF of 1.42
# 10 terms have an IDF of 1.41
# 8 terms have an IDF of 1.40
# 7 terms have an IDF of 1.39
# 3 terms have an IDF of 1.38
# 14 terms have an IDF of 1.38
# 7 terms have an IDF of 1.37
# 7 terms have an IDF of 1.36
# 5 terms have an IDF of 1.35
# 9 terms have an IDF of 1.34
# 4 terms have an IDF of 1.34
# 2 terms have an IDF of 1.33
# 5 terms have an IDF of 1.32
# 8 terms have an IDF of 1.31
# 4 terms have an IDF of 1.30
# 8 terms have an IDF of 1.30
# 4 terms have an IDF of 1.29
# 5 terms have an IDF of 1.28
# 8 terms have an IDF of 1.27
# 9 terms have an IDF of 1.27
# 4 terms have an IDF of 1.26
# 4 terms have an IDF of 1.25
# 3 terms have an IDF of 1.24
# 5 terms have an IDF of 1.24
# 5 terms have an IDF of 1.23
# 4 terms have an IDF of 1.22
# 3 terms have an IDF of 1.21
# 2 terms have an IDF of 1.21
# 5 terms have an IDF of 1.20
# 6 terms have an IDF of 1.19
# 5 terms have an IDF of 1.19
# 3 terms have an IDF of 1.18
# 4 terms have an IDF of 1.17
# 4 terms have an IDF of 1.17
# 4 terms have an IDF of 1.16
# 10 terms have an IDF of 1.15
# 3 terms have an IDF of 1.15
# 2 terms have an IDF of 1.14
# 3 terms have an IDF of 1.13
# 1 terms have an IDF of 1.13
# 2 terms have an IDF of 1.11
# 4 terms have an IDF of 1.11
# 4 terms have an IDF of 1.10
# 7 terms have an IDF of 1.09
# 5 terms have an IDF of 1.09
# 3 terms have an IDF of 1.08
# 7 terms have an IDF of 1.08
# 10 terms have an IDF of 1.07
# 3 terms have an IDF of 1.06
# 3 terms have an IDF of 1.06
# 3 terms have an IDF of 1.05
# 6 terms have an IDF of 1.05
# 7 terms have an IDF of 1.04
# 1 terms have an IDF of 1.03
# 5 terms have an IDF of 1.03
# 5 terms have an IDF of 1.02
# 4 terms have an IDF of 1.01
# 4 terms have an IDF of 1.00
# 4 terms have an IDF of 1.00
# 9 terms have an IDF of 0.99
# 1 terms have an IDF of 0.99
# 3 terms have an IDF of 0.98
# 3 terms have an IDF of 0.98
# 1 terms have an IDF of 0.97
# 3 terms have an IDF of 0.96
# 3 terms have an IDF of 0.96
# 5 terms have an IDF of 0.95
# 3 terms have an IDF of 0.95
# 1 terms have an IDF of 0.94
# 3 terms have an IDF of 0.93
# 2 terms have an IDF of 0.92
# 6 terms have an IDF of 0.92
# 1 terms have an IDF of 0.91
# 1 terms have an IDF of 0.91
# 1 terms have an IDF of 0.90
# 2 terms have an IDF of 0.90
# 4 terms have an IDF of 0.89
# 5 terms have an IDF of 0.89
# 4 terms have an IDF of 0.88
# 3 terms have an IDF of 0.88
# 1 terms have an IDF of 0.86
# 4 terms have an IDF of 0.86
# 2 terms have an IDF of 0.86
# 3 terms have an IDF of 0.85
# 2 terms have an IDF of 0.85
# 4 terms have an IDF of 0.84
# 4 terms have an IDF of 0.84
# 1 terms have an IDF of 0.83
# 1 terms have an IDF of 0.83
# 2 terms have an IDF of 0.82
# 2 terms have an IDF of 0.82
# 2 terms have an IDF of 0.81
# 5 terms have an IDF of 0.81
# 4 terms have an IDF of 0.80
# 3 terms have an IDF of 0.80
# 1 terms have an IDF of 0.79
# 1 terms have an IDF of 0.78
# 1 terms have an IDF of 0.78
# 3 terms have an IDF of 0.77
# 1 terms have an IDF of 0.77
# 3 terms have an IDF of 0.77
# 1 terms have an IDF of 0.76
# 2 terms have an IDF of 0.76
# 2 terms have an IDF of 0.74
# 1 terms have an IDF of 0.74
# 1 terms have an IDF of 0.73
# 3 terms have an IDF of 0.73
# 1 terms have an IDF of 0.73
# 2 terms have an IDF of 0.72
# 3 terms have an IDF of 0.72
# 2 terms have an IDF of 0.71
# 2 terms have an IDF of 0.71
# 2 terms have an IDF of 0.70
# 2 terms have an IDF of 0.70
# 1 terms have an IDF of 0.70
# 2 terms have an IDF of 0.68
# 3 terms have an IDF of 0.68
# 1 terms have an IDF of 0.67
# 4 terms have an IDF of 0.67
# 1 terms have an IDF of 0.67
# 2 terms have an IDF of 0.66
# 2 terms have an IDF of 0.66
# 2 terms have an IDF of 0.65
# 2 terms have an IDF of 0.65
# 2 terms have an IDF of 0.65
# 2 terms have an IDF of 0.64
# 2 terms have an IDF of 0.64
# 2 terms have an IDF of 0.63
# 1 terms have an IDF of 0.63
# 2 terms have an IDF of 0.62
# 1 terms have an IDF of 0.62
# 1 terms have an IDF of 0.61
# 1 terms have an IDF of 0.60
# 1 terms have an IDF of 0.59
# 1 terms have an IDF of 0.58
# 1 terms have an IDF of 0.57
# 1 terms have an IDF of 0.57
# 2 terms have an IDF of 0.56
# 2 terms have an IDF of 0.56
# 1 terms have an IDF of 0.56
# 4 terms have an IDF of 0.55
# 2 terms have an IDF of 0.55
# 1 terms have an IDF of 0.54
# 3 terms have an IDF of 0.54
# 2 terms have an IDF of 0.53
# 1 terms have an IDF of 0.52
# 4 terms have an IDF of 0.52
# 1 terms have an IDF of 0.51
# 2 terms have an IDF of 0.49
# 1 terms have an IDF of 0.49
# 2 terms have an IDF of 0.48
# 1 terms have an IDF of 0.47
# 2 terms have an IDF of 0.47
# 1 terms have an IDF of 0.46
# 1 terms have an IDF of 0.46
# 3 terms have an IDF of 0.46
# 2 terms have an IDF of 0.45
# 1 terms have an IDF of 0.45
# 1 terms have an IDF of 0.45
# 1 terms have an IDF of 0.43
# 1 terms have an IDF of 0.43
# 1 terms have an IDF of 0.42
# 1 terms have an IDF of 0.42
# 2 terms have an IDF of 0.41
# 2 terms have an IDF of 0.40
# 1 terms have an IDF of 0.40
# 2 terms have an IDF of 0.39
# 1 terms have an IDF of 0.39
# 1 terms have an IDF of 0.38
# 2 terms have an IDF of 0.34
# 1 terms have an IDF of 0.33
# 1 terms have an IDF of 0.33
# 1 terms have an IDF of 0.31
# 1 terms have an IDF of 0.30
# 2 terms have an IDF of 0.29
# 1 terms have an IDF of 0.28
# 1 terms have an IDF of 0.28
# 1 terms have an IDF of 0.26
# 1 terms have an IDF of 0.21
# 1 terms have an IDF of 0.15
# 1 terms have an IDF of 0.09
